# %% [markdown]
# # Project 1

# %% [markdown]
# ## Step 1: Load the data and perform basic operations.

# %% [markdown]
# ##### 1. Load the data in using pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats



act = pd.read_csv("act.csv")
sat = pd.read_csv("sat.csv")

# %% [markdown]
# ##### 2. Print the first ten rows of each dataframe.

# %%
sat.head(10)
# Out:
#    Unnamed: 0                 State Participation  \
# 0           0               Alabama            5%
# 1           1                Alaska           38%
# 2           2               Arizona           30%
# 3           3              Arkansas            3%
# 4           4            California           53%
# 5           5              Colorado           11%
# 6           6           Connecticut          100%
# 7           7              Delaware          100%
# 8           8  District of Columbia          100%
# 9           9               Florida           83%
#
#    Evidence-Based Reading and Writing  Math  Total
# 0                                 593   572   1165
# 1                                 547   533   1080
# 2                                 563   553   1116
# 3                                 614   594   1208
# 4                                 531   524   1055
# 5                                 606   595   1201
# ...

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
# Unnamed: 0                            51 non-null int64
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 2.5+ KB

# %%
act.head(10)
# Out:
#    Unnamed: 0                 State Participation  English  Math  Reading  \
# 0           0              National           60%     20.3  20.7     21.4
# 1           1               Alabama          100%     18.9  18.4     19.7
# 2           2                Alaska           65%     18.7  19.8     20.4
# 3           3               Arizona           62%     18.6  19.8     20.1
# 4           4              Arkansas          100%     18.9  19.0     19.7
# 5           5            California           31%     22.5  22.7     23.1
# 6           6              Colorado          100%     20.1  20.3     21.2
# 7           7           Connecticut           31%     25.5  24.6     25.6
# 8           8              Delaware           18%     24.1  23.4     24.8
# 9           9  District of Columbia           32%     24.4  23.5     24.9
#
#    Science  Composite
# 0     21.0       21.0
# 1     19.4       19.2
# 2     19.9       19.8
# 3     19.8       19.7
# 4     19.5       19.4
# ...

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
# Unnamed: 0       52 non-null int64
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.3+ KB

# %% [markdown]
# ##### 3. Describe in words what each variable (column) is.

# %%
sat.describe()
# Out:
#        Unnamed: 0  Evidence-Based Reading and Writing        Math        Total
# count   51.000000                           51.000000   51.000000    51.000000
# mean    25.000000                          569.117647  547.627451  1126.098039
# std     14.866069                           45.666901   84.909119    92.494812
# min      0.000000                          482.000000   52.000000   950.000000
# 25%     12.500000                          533.500000  522.000000  1055.500000
# 50%     25.000000                          559.000000  548.000000  1107.000000
# 75%     37.500000                          613.000000  599.000000  1212.000000
# max     50.000000                          644.000000  651.000000  1295.000000

# %%
act.describe()
# Out:
#        Unnamed: 0    English       Math    Reading    Science  Composite
# count   52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean    25.500000  20.919231  21.173077  22.001923  21.040385  21.509615
# std     15.154757   2.332132   1.963602   2.048672   3.151113   2.002083
# min      0.000000  16.300000  18.000000  18.100000   2.300000  17.800000
# 25%     12.750000  19.000000  19.400000  20.475000  19.900000  19.800000
# 50%     25.500000  20.550000  20.900000  21.700000  21.150000  21.400000
# 75%     38.250000  23.300000  23.100000  24.125000  22.525000  23.600000
# max     51.000000  25.500000  25.300000  26.000000  24.900000  25.500000

# %% [markdown]
# SAT Columns Description
#
# Unnamed: Index column is the distinctive key for every row of data set
#
# State: The state data has its origin from
#
# Participation: The rate of successful completion of the exam
#
# Evidence-Based Reading and Writing: Exam score average (mean) of the graduates who took the test in that state
#
# Math: Exam score average (mean) of the graduates who took the test in that state
#
# Total: The aggregate exam score average (mean) of the graduates who took the test in that state

# %% [markdown]
# ACT Columns Description
#
# Unnamed: Index column is the distinctive key for every row of dataset
#
# State: The state data has its origin from
#
# Participation: The rate of successful completion of the exam
#
# English: Exam score average (mean) of the graduates who took the test in that state
#
# Math:  Exam score average (mean) of the graduates who took the test in that state
#
# Reading:  Exam score average (mean) of the graduates who took the test in that state
#
# Science:  Exam score average (mean) of the graduates who took the test in that state
#
# Composite: The aggregate exam score average (mean) of the graduates who took the test in that state

# %% [markdown]
# ##### 4. Does the data look complete? Are there any obvious issues with the observations?

# %%
#the National average row from ACT data set needs to be dropped, since it’s not present in SAT data.
act = act.drop([0])

# %%
sat.head(3)
# Out:
#    Unnamed: 0    State Participation  Evidence-Based Reading and Writing  \
# 0           0  Alabama            5%                                 593
# 1           1   Alaska           38%                                 547
# 2           2  Arizona           30%                                 563
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116

# %% [markdown]
# ##### 5. Print the types of each column.

# %%
print('Print the types of each column ACT')
for column in act.columns:
    print(type(column))
# Out:
# Print the types of each column ACT
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print('Print the types of each column SAT')
for column in sat.columns:
    print(type(column))

# %% [markdown]
# ##### 6. Do any types need to be reassigned? If so, go ahead and do it.

# %% [markdown]
# we need to reassign appropriate data types, in order to perform mathematical operations and statistical analysis on the numeric columns.

# %%
sat['Participation'] = (sat['Participation']).str.replace('%','').astype(float)

# %%
sat.Participation.head(3)
# Out:
# 0     5.0
# 1    38.0
# 2    30.0
# Name: Participation, dtype: float64

# %%
act['Participation'] = act['Participation'].str.replace('%','').str.replace('%','').astype(float)

# %%
act.Participation.head(3)
# Out:
# 1    100.0
# 2     65.0
# 3     62.0
# Name: Participation, dtype: float64

# %%
sat.Participation = pd.to_numeric(sat.Participation, downcast = 'float')

# %%
np.dtype(sat.Participation) #Turn the column from a string to a float
# Out:
# dtype('float32')

# %%
act.Participation = pd.to_numeric(act.Participation, downcast = 'float')

# %%
np.dtype(act.Participation) #Same thing with the Participation column in SAT¶
# Out:
# dtype('float32')

# %%
act.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
sat.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
act.head(3) # Dropping the Unnamed columns
# Out:
#      State  Participation  English  Math  Reading  Science  Composite
# 1  Alabama          100.0     18.9  18.4     19.7     19.4       19.2
# 2   Alaska           65.0     18.7  19.8     20.4     19.9       19.8
# 3  Arizona           62.0     18.6  19.8     20.1     19.8       19.7

# %%
sat.head(3) # Dropping the Unnamed columns
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama            5.0                                 593   572   1165
# 1   Alaska           38.0                                 547   533   1080
# 2  Arizona           30.0                                 563   553   1116

# %% [markdown]
# # 10. Change the names of the columns so you can distinguish between the SAT columns and the ACT columns.

# %%
sat.rename(columns = {
    'Participation': 'SAT_Success_Rate',
    'Evidence-Based Reading and Writing': 'SAT_EBRW', 
    'Math': 'SAT_Math',
    'Total': 'SAT_Total'
}, inplace=True)

act.rename(columns = {
    'Participation': 'ACT_Success_Rate',
    'English': 'ACT_English',
    'Math': 'ACT_Math',
    'Reading': 'ACT_Reading',
    'Science': 'ACT_Science',
    'Composite': 'ACT_Composite'
}, inplace=True)

# %% [markdown]
# ##### 7. Create a dictionary for each column mapping the State to its respective value for that column. (For example, you should have three SAT dictionaries.)

# %%
sat_rate = sat.set_index('State')['SAT_Success_Rate'].to_dict()
sat_ela = sat.set_index('State')['SAT_EBRW'].to_dict()
sat_math = sat.set_index('State')['SAT_Math'].to_dict()
sat_total = sat.set_index('State')['SAT_Total'].to_dict()

# %%
act_rate = act.set_index('State')['ACT_Success_Rate'].to_dict()
act_english = act.set_index('State')['ACT_English'].to_dict()
act_math  = act.set_index('State')['ACT_Math'].to_dict()
act_reading = act.set_index('State')['ACT_Reading'].to_dict()
act_science = act.set_index('State')['ACT_Science'].to_dict()
act_composite = act.set_index('State')['ACT_Composite'].to_dict()

# %% [markdown]
# ##### 8. Create one dictionary where each key is the column name, and each value is an iterable (a list or a Pandas Series) of all the values in that column.

# %%
sat_dict = {}
for i in sat:
    dict2 = {i:sat[i]}
    sat_dict.update(dict2)

act_dict = {}
for i in act:
    dict2 = {i:act[i]}
    act_dict.update(dict2)

# %% [markdown]
# ##### 9. Merge the dataframes on the state column.

# %%
test_data = pd.merge(sat, act, on='State')

# %%
test_data.head(3)
# Out:
#      State  SAT_Success_Rate  SAT_EBRW  SAT_Math  SAT_Total  ACT_Success_Rate  \
# 0  Alabama               5.0       593       572       1165             100.0
# 1   Alaska              38.0       547       533       1080              65.0
# 2  Arizona              30.0       563       553       1116              62.0
#
#    ACT_English  ACT_Math  ACT_Reading  ACT_Science  ACT_Composite
# 0         18.9      18.4         19.7         19.4           19.2
# 1         18.7      19.8         20.4         19.9           19.8
# 2         18.6      19.8         20.1         19.8           19.7

# %% [markdown]
# ##### 11. Print the minimum and maximum of each numeric column in the data frame.

# %%
test_data.describe().loc[['min', 'max']]
# Out:
#      SAT_Success_Rate  SAT_EBRW  SAT_Math  SAT_Total  ACT_Success_Rate  \
# min               2.0     482.0      52.0      950.0               8.0
# max             100.0     644.0     651.0     1295.0             100.0
#
#      ACT_English  ACT_Math  ACT_Reading  ACT_Science  ACT_Composite
# min         16.3      18.0         18.1          2.3           17.8
# max         25.5      25.3         26.0         24.9           25.5

# %%
test_data.min()
# Out:
# State               Alabama
# SAT_Success_Rate          2
# SAT_EBRW                482
# SAT_Math                 52
# SAT_Total               950
# ACT_Success_Rate          8
# ACT_English            16.3
# ACT_Math                 18
# ACT_Reading            18.1
# ACT_Science             2.3
# ACT_Composite          17.8
# dtype: object

# %%
test_data.max()
# Out:
# State               Wyoming
# SAT_Success_Rate        100
# SAT_EBRW                644
# SAT_Math                651
# SAT_Total              1295
# ACT_Success_Rate        100
# ACT_English            25.5
# ACT_Math               25.3
# ACT_Reading              26
# ACT_Science            24.9
# ACT_Composite          25.5
# dtype: object

# %% [markdown]
# ##### 12. Write a function using only list comprehensions, no loops, to compute standard deviation. Using this function, calculate the standard deviation of each numeric column in both data sets. Add these to a list called `sd`.
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$

# %%
numeric_columns =['SAT_Success_Rate', 'SAT_EBRW', 'SAT_Math', 'SAT_Total',
    'ACT_Success_Rate', 'ACT_English', 'ACT_Math', 'ACT_Reading',
    'ACT_Science', 'ACT_Composite']

sd = [test_data[i].std() for i in numeric_columns]
sd
# Out:
# [35.27662658691406,
#  45.66690138768932,
#  84.90911865855486,
#  92.49481172519046,
#  32.14084243774414,
#  2.35367713980303,
#  1.9819894936505533,
#  2.0672706264873146,
#  3.182462975155452,
#  2.020694891154341]

# %% [markdown]
# ## Step 2: Manipulate the dataframe

# %% [markdown]
# ##### 13. Turn the list `sd` into a new observation in your dataset.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-4e6d624f6025> in <module>()
# ----> 1 sd = sd.append("std_list")
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %% [markdown]
# ##### 14. Sort the dataframe by the values in a numeric column (e.g. observations descending by SAT participation rate)

# %%
test_data.sort_values('SAT_Success_Rate', ascending=False, inplace=True)

# %% [markdown]
# ##### 15. Use a boolean filter to display only observations with a score above a certain threshold (e.g. only states with a participation rate above 50%)

# %%
test_data.query('SAT_Success_Rate>50')
# Out:
#                    State  SAT_Success_Rate  SAT_EBRW  SAT_Math  SAT_Total  \
# 8   District of Columbia             100.0       482       468        950
# 22              Michigan             100.0       509       495       1005
# 6            Connecticut             100.0       530       512       1041
# 7               Delaware             100.0       503       492        996
# 29         New Hampshire              96.0       532       520       1052
# 19                 Maine              95.0       513       499       1012
# 12                 Idaho              93.0       513       493       1005
# 9                Florida              83.0       520       497       1017
# 21         Massachusetts              76.0       555       551       1107
# 39          Rhode Island              71.0       539       524       1062
# 30            New Jersey              70.0       530       526       1056
# 20              Maryland              69.0       536        52       1060
# ...

# %% [markdown]
# ## Step 3: Visualize the data

# %% [markdown]
# ##### 16. Using MatPlotLib and PyPlot, plot the distribution of the Rate columns for both SAT and ACT using histograms. (You should have two histograms. You might find [this link](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes) helpful in organizing one plot above the other.)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,10) )
sns.distplot(test_data['SAT_Success_Rate'], axlabel='SAT Participation Rate', ax=ax1)
sns.distplot(test_data['ACT_Success_Rate'], axlabel='ACT Participation Rate', ax=ax2);
# Out:
# /Users/Hakob/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/Hakob/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The SAT participation rate seems to be right skewed, with a mean of about 39.8, with a range between 0 and 100, the ACT Participation rate is right skewed, with a mean of about 65.3 and a range of 0 to 100. What we can infer from this is that among the high school graduates who take these exams, the ACT experiences a higher participation rate on average than the SAT. With participation rate being the main metric by which the College board is measuring sucess, we can say that the ACT performs stronger in this regard.

# %% [markdown]
# ##### 17. Plot the Math(s) distributions from both data sets.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,10) )
sns.distplot(test_data['SAT_Math'], axlabel='SAT Math Scores', ax=ax1)
sns.distplot(test_data['ACT_Math'], axlabel='ACT Math Scores', ax=ax2);
# Out:
# /Users/Hakob/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/Hakob/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The SAT Math scores have a very strong right skew, with a mean of 547.6, a range of 599 and a standard deviation of 84. Maryland seems to be an outlier where the average math score for that state was 52, even with an over-all participation rate of 68%. Looking at the numbers, we can impune that neither the skew nor mean of the SAT Math scores is significantly affected (median = 548) .
# As for the ACT Math scores, the distribution is skewed right with a mean of 21, a range of 7.3 and a standard deviation of 1.98. What we can infer is that of the high school gratuate who take these exams, performance on the math portion of each exam is similarly distributed.

# %% [markdown]
# ##### 18. Plot the Verbal distributions from both data sets.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,10) )
sns.distplot(test_data['SAT_EBRW'], bins=10, axlabel='SAT Verbal Scores', ax=ax1)
sns.distplot(test_data['ACT_Reading'], bins=10, axlabel='ACT Verbal scores', ax=ax2);
# Out:
# /Users/Hakob/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/Hakob/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# The SAT Verbal distribution has a right skew, with a mean of 569, range of 162, and a standard deviation of 45.
# The ACT Verbal distribution is approoximately normally distributed, with a mean of 22, a range of 8, and a standard deviation of 2.

# %% [markdown]
# ##### 19. When we make assumptions about how data are distributed, what is the most common assumption?

# %% [markdown]
# Note: The most common assumption about a distribution is that it's a normal distribution / a symetric distribution / Gaussian distribution.

# %% [markdown]
# ##### 20. Does this assumption hold true for any of our columns? Which?

# %% [markdown]
# act_part is skewed left/negative
#
# act_eng is skewed right/positive
#
# act_math is skewed right/positive
#
# act_read is skewed right/positive
#
# act_sci is skewed left/negative
#
# sat_part is skewed right/positive
#
# sat_rnw is skewed right/positive
#
# sat_math is skewed left/negativ

# %% [markdown]
# # 21. Plot some scatterplots examining relationships between all variables.

# %%
# Scatterplots of SAT Participation Rate by SAT Total & SAT Math
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,10) )
sns.regplot(test_data['SAT_Success_Rate'],test_data['SAT_Total'], ax=ax1)
sns.regplot(test_data['SAT_Success_Rate'], test_data['SAT_Math'], ax=ax2)
ax1.set_title("SAT Participation by Average Total Score")
ax2.set_title("SAT Participation by Average Math Score");

# %%
# Scatterplot of SAT Participation rate  by Average ELA Score
fig, ax = plt.subplots(nrows=1, ncols=1)
sns.regplot(test_data['SAT_Success_Rate'],test_data['SAT_EBRW'])
ax.set_title("SAT Participation by Average ELA Score");

# %%
# Scatterplots of ACT Participation Rate by ACT Composite & ACT Math
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,10) )
sns.regplot(test_data['ACT_Success_Rate'], test_data['ACT_Composite'], ax=ax1)
sns.regplot(test_data['ACT_Success_Rate'], test_data['ACT_Math'], ax=ax2)
ax1.set_title("ACT Participation by Average Composite Score")
ax2.set_title("ACT Participation by Average Math Score");

# %%
# Scatterplots of ACT Participation Rate by ACT Science & ACT Math
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(20,10) )
sns.regplot(test_data['ACT_Success_Rate'], test_data['ACT_Reading'], ax=ax1)
sns.regplot(test_data['ACT_Success_Rate'], test_data['ACT_Science'], ax=ax2)
ax1.set_title("ACT Participation by Average Reading Score")
ax2.set_title("ACT Participation by Average Science Score");

# %% [markdown]
# ##### 22. Are there any interesting relationships to note?

# %% [markdown]
# Scatterplot Observations
#
# Out of all the scatterplots we have plotted with regards to participation rate, none of them exhibit a positive linear relationship. In other words, it can be widely observed that as participation moves closer to 100%, average scores in general go down.
#
# Generally speaking, we can thus observe that most of thes scatterplots show a strong, negative, linear association between the participation rate and the average scores. The only instances where this negative linear association is not as strong are with the ACT Rate with respec to ACT Science, and the SAT Rate with respect to SAT Math.
#
# Individual test scores seem to be higher in states where the participation rate for a given exam is lower.
#
# States where we observe higher participation rate in one exam, tend to have a lower participation rate in the other.

# %% [markdown]
# ##### 23. Create box plots for each variable.

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
sns.boxplot(test_data['SAT_Success_Rate'], ax=ax1)
sns.boxplot(test_data['SAT_Math'], ax=ax2);

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
sns.boxplot(test_data['SAT_EBRW'], ax=ax1)
sns.boxplot(test_data['SAT_Total'], ax=ax2);

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
sns.boxplot(test_data['ACT_Reading'], ax=ax1)
sns.boxplot(test_data['ACT_Science'], ax=ax2);

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
sns.boxplot(test_data['ACT_English'], ax=ax1)
sns.boxplot(test_data['ACT_Success_Rate'], ax=ax2);

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %%
plt.figure(figsize=(16,9))
sns.heatmap(test_data.corr(), annot = True, cmap="PiYG")

# %% [markdown]
# ## Step 4: Descriptive and Inferential Statistics

# %% [markdown]
# ##### 24. Summarize each distribution. As data scientists, be sure to back up these summaries with statistics. (Hint: What are the three things we care about when describing distributions?)

# %%
test_data.plot(kind='hist') #figsize=(10,7)
plt.savefig('/Users/Hakob/Pictures/stat_spread.jpg', format = 'jpg', dpi = 1000);

# %%
test_data.mean()
# Out:
# SAT_Success_Rate      39.803922
# SAT_EBRW             569.117647
# SAT_Math             547.627451
# SAT_Total           1126.098039
# ACT_Success_Rate      65.254902
# ACT_English           20.931373
# ACT_Math              21.182353
# ACT_Reading           22.013725
# ACT_Science           21.041176
# ACT_Composite         21.519608
# dtype: float64

# %%
test_data.median()
# Out:
# SAT_Success_Rate      38.0
# SAT_EBRW             559.0
# SAT_Math             548.0
# SAT_Total           1107.0
# ACT_Success_Rate      69.0
# ACT_English           20.7
# ACT_Math              20.9
# ACT_Reading           21.8
# ACT_Science           21.3
# ACT_Composite         21.4
# dtype: float64

# %%
test_data.std()
# Out:
# SAT_Success_Rate    35.276632
# SAT_EBRW            45.666901
# SAT_Math            84.909119
# SAT_Total           92.494812
# ACT_Success_Rate    32.140842
# ACT_English          2.353677
# ACT_Math             1.981989
# ACT_Reading          2.067271
# ACT_Science          3.182463
# ACT_Composite        2.020695
# dtype: float64

# %% [markdown]
# ##### 25. Summarize each relationship. Be sure to back up these summaries with statistics.

# %% [markdown]
# act_Success_Rate  is skewed left/negative                               The distribution is negatively skewed, also seen as the mean < median.
# The standard deviation is somewhat big, which indicates that there is a big spread from the mean value.
#
# act_eng is skewed right/positive
# The distribution is positivly skewed, also seen as the mean > median.
# The standard deviation is quite big, which indicates that there is a quite big spread from the mean value.
#
# act_math is skewed right/positive
# Comment: The distribution is positivly skewed, also seen as the mean > median.
# The standard deviation is quite big, which indicates that there is a quite big spread from the mean value.
#
# act_read is skewed right/positive
# Comment: The distribution is positivly skewed, also seen as the mean > median.
# The standard deviation is quite big, which indicates that there is a quite big spread from the mean value.
#
#
# act_sci is skewed left/negative
# Comment: The distribution is negativly skewed, also seen as the mean < median.
# The standard deviation is somewhat big, which indicates that there is a big spread from the mean value.
#
#
# sat_part is skewed right/positive
# Comment: The distribution is positivly skewed, also seen as the mean > median.
# The standard deviation is very big, which indicates that there is a very big spread from the mean value.
#
#
# sat_rnw is skewed right/positive
# Comment: The distribution is positivly skewed, also seen as the mean > median.
# The standard deviation is somewhat big, which indicates that there is a big spread from the mean value.
#
#
# sat_math is skewed left/negative
# Comment: The distribution is negativly skewed, also seen as the mean < median.
# The standard deviation is a little bit big, which indicates that there is kind of a big spread from the mean value.

# %% [markdown]
# You can clearly see that there visualy seems to be a relation between some variables.
#
# All the column that are parts of the ACT
# All the column that are parts of the SAT
# However they are part of the same test and it can be other factors influencing them to move in the same direction.
#
# Have instead chosen to study columns that kind of exsists in both test.
# Average participation rate, math and verbal(eng and read)/readandwrite.
# You can see a trend in all of them
#
# Above look at the 3 graphs that I choose to do.
# I did not think it was any point in looking at test part in one test that had no corresponding part in the other test.
#
# CORRELATION participation rate and columns from same test are interesting.

# %% [markdown]
# ##### 26. Execute a hypothesis test comparing the SAT and ACT participation rates. Use $\alpha = 0.05$. Be sure to interpret your results.

# %%
# Hypothesis test# Hypoth 
result = stats.ttest_ind(test_data['SAT_Success_Rate'],test_data['ACT_Success_Rate'])
result.statistic, result.pvalue
a = .05

if result.pvalue < a:
    print('We can confidently reject the null hypothesis!')
# Out:
# We can confidently reject the null hypothesis!

# %% [markdown]
# Since our resulting p-value is below 0.05, this means that we can reject the null hypothesis, and infer that there is a meaningful statistical difference between ACT and SAT participation rates.
#
# This is interesting! But we must look into this futher. Let's do that by looking at the 95% confidence interval for participation rates between the SAT and ACT

# %% [markdown]
# ##### 27. Generate and interpret 95% confidence intervals for SAT and ACT participation rates.

# %%
# Confidence Interval SAT Rate
z = 1.96 # z score for a CI of 95% 
sample_mean = np.mean(test_data['SAT_Success_Rate'])
sample_sem = np.std(test_data['SAT_Success_Rate'])/np.sqrt(len(test_data['SAT_Success_Rate']))

lower_end = sample_mean - z * sample_sem
high_end = sample_mean + z*sample_sem
(lower_end,high_end)
# Out:
# (30.217466587225054, 49.390374904474164)

# %%
# Confidence Interval for ACT Rate
z = 1.96 # z score for a CI of 95% 
sample_mean = np.mean(test_data['ACT_Success_Rate'])
sample_sem = np.std(test_data['ACT_Success_Rate'])/np.sqrt(len(test_data['ACT_Success_Rate']))

low_end = sample_mean - z* sample_sem
high_end = sample_mean + z * sample_sem
(low_end,high_end)
# Out:
# (56.52060350805338, 73.98920789331382)

# %% [markdown]
# ##### 28. Given your answer to 26, was your answer to 27 surprising? Why?

# %% [markdown]
# 95% of the time, a given state's SAT participation rate will fall between 30% and 49.3%. 95% of the time, a given state's ACT participation rate will fall between 56.5% and 73.9% This disparity in confidence intervals is not a surprising finding, given the fact that in executing the hypothesis test, we were able to reject the null hupothesis and infer that the difference between SAT and ACT participation rates would be statistically different.

# %% [markdown]
# ##### 29. Is it appropriate to generate correlation between SAT and ACT math scores? Why?

# %% [markdown]
# With regards to ACT and SAT Math scores, given the data we have now, it would not be appropriate to generate a correlation between the two. They are two different exams, and performance on one doesn't have an correlative effect of performance on the other. The only scenario where we might want to investigate whether there is a correlation between the two is if we were able to subselect the group of students who took both exams one after the other. But trying to do so based of state averages is tantamount to scientific malpractice.

# %% [markdown]
# ##### 30. Suppose we only seek to understand the relationship between SAT and ACT data in 2017. Does it make sense to conduct statistical inference given the data we have? Why?

# %% [markdown]
# Finally, supposing we only seek to understand the relationship between SAT and ACT data in 2017, it does make sense to conduct limited statistical inference given the data we have. I stress limited is because, even though we techniocally have a good enough sample size to conduct inferences and perform statistically representatitve analyses, the level of detail of this data set leaves a lot to be desired, as outlined in the Data Integrity Check section.

# %% [markdown]
# # Correlation

# %% [markdown]
# There is a strong negativ correlation within
# ACT:
#
# • High participation -> low result score (especially for english, math and reading).
# If you have low grades you do the test and hope for a good result. So you can try to ap- ply to a school on your test score instead of your grades.
#
# •Fewer participants -> higher scores
# You are really good in a subject and have good grades, but want to get in to a speciHc school. Therefor you take the test.

# %% [markdown]
# SAT
# There is strong negativ correlation within
#
# • High participation -> low result on reading and writing.
# Same theory as above to why.
#
# Participation rate in the 2 tests
# For the participation rate in the 2 tests it
# seems like if the participation rate is high in one test, it’s low in the other. In other words it’s a negativ correlation. Here you can explore more if you want to look more into the correlation.

# %% [markdown]
# Conclusion —  Recommendation to SAT board
#
#
# Start with looking more into SAT reading and writing part since that part in strongly negativly correlted with the SAT Average participation rate. More participants -> lower scores in the reading and writing part Less participants -> higher scores in the reading and writing part
# The verbal parts between the two tests are not that strongly correlated.Therefor a directed effort might be need and not a broader approach.
#
# Further start on focusing on states with low participation rate. For example Iowa, Mississippi, North Dakota and other states with low SAT participation rate. The participation rate for the two tests are high/low in diferent states.   With that said it might be a attitude question among the schools or the students.
# With more time you can dive deeper into this data, focusing more on specific correlation or what it looks like in specific states.
# Further areas of interest:
#
# Survey (attitude of the students + do the schools ask for diferent things)
#
# • Higher participation to any cost (lower scores?)
#
# • Other countries (best practice studie)
